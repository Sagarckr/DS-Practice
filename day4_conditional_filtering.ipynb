# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Dataset/Employees.csv")
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          100     Steven      King     SKING  515.123.4567  6/17/2003
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4          104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
#
#     JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# 0  AD_PRES   24000             NaN         NaN           90.0
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0
# 3  IT_PROG    9000             NaN       102.0           60.0
# 4  IT_PROG    6000             NaN       103.0           60.0

# %%
emp_sal = df['SALARY']>15000
emp_sal
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 106    False
# 107    False
# 108    False
# 109    False
# 110    False
# Name: SALARY, Length: 111, dtype: bool

# %%
emp_sal = df[df['SALARY']>15000]
emp_sal
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          100     Steven      King     SKING  515.123.4567  6/17/2003
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
#
#     JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# 0  AD_PRES   24000             NaN         NaN           90.0
# 1    AD_VP   17000             NaN       100.0           90.0
# 2    AD_VP   17000             NaN       100.0           90.0

# %%
emp_sal = df.where(df['SALARY'] > 15000).dropna(how='all')
emp_sal
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0        100.0     Steven      King     SKING  515.123.4567  6/17/2003
# 1        101.0      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2        102.0        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
#
#     JOB_ID   SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# 0  AD_PRES  24000.0             NaN         NaN           90.0
# 1    AD_VP  17000.0             NaN       100.0           90.0
# 2    AD_VP  17000.0             NaN       100.0           90.0

# %%
df['Status'] = np.where(df['SALARY'] > 15000, 'High', 'Low')
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          100     Steven      King     SKING  515.123.4567  6/17/2003
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4          104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
#
#     JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID Status
# 0  AD_PRES   24000             NaN         NaN           90.0   High
# 1    AD_VP   17000             NaN       100.0           90.0   High
# 2    AD_VP   17000             NaN       100.0           90.0   High
# 3  IT_PROG    9000             NaN       102.0           60.0    Low
# 4  IT_PROG    6000             NaN       103.0           60.0    Low

# %%
emp_salary = df[(df['SALARY'] >= 10000) & (df['SALARY'] < 18000)]
emp_salary[['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'SALARY']].head()
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME  SALARY
# 1           101      Neena    Kochhar   17000
# 2           102        Lex    De Haan   17000
# 8           108      Nancy  Greenberg   12008
# 14          114        Den   Raphaely   11000
# 45          145       John    Russell   14000

# %%
emp_salary_between = df[df['SALARY'].between(10000,18000)] # between is inclusive
emp_salary_between.head()
# Out:
#     EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL        PHONE_NUMBER  \
# 1           101      Neena    Kochhar  NKOCHHAR        515.123.4568
# 2           102        Lex    De Haan   LDEHAAN        515.123.4569
# 8           108      Nancy  Greenberg  NGREENBE        515.124.4569
# 14          114        Den   Raphaely  DRAPHEAL        515.127.4561
# 45          145       John    Russell   JRUSSEL  011.44.1344.429268
#
#     HIRE_DATE  JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID  \
# 1   9/21/2005   AD_VP   17000             NaN       100.0           90.0
# 2   1/13/2001   AD_VP   17000             NaN       100.0           90.0
# 8   8/17/2002  FI_MGR   12008             NaN       101.0          100.0
# 14  12/7/2002  PU_MAN   11000             NaN       100.0           30.0
# 45  10/1/2004  SA_MAN   14000             0.4       100.0           80.0
#
#    Status
# 1    High
# 2    High
# 8     Low
# 14    Low
# 45    Low

# %%
## Find employees details who work in job AD_VP and IT_PROG.
emp_filter = df[(df['JOB_ID']=='AD_VP') | (df['JOB_ID'] == "IT_PROG")]
emp_filter.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4          104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
# 5          105      David    Austin   DAUSTIN  590.423.4569  6/25/2005
#
#     JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID Status
# 1    AD_VP   17000             NaN       100.0           90.0   High
# 2    AD_VP   17000             NaN       100.0           90.0   High
# 3  IT_PROG    9000             NaN       102.0           60.0    Low
# 4  IT_PROG    6000             NaN       103.0           60.0    Low
# 5  IT_PROG    4800             NaN       103.0           60.0    Low

# %%
emp_job_in = df[df['JOB_ID'].isin(['AD_VP','IT_PROG'])]
emp_job_in
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 1          101      Neena    Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2          102        Lex    De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3          103  Alexander     Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4          104      Bruce      Ernst    BERNST  590.423.4568  5/21/2007
# 5          105      David     Austin   DAUSTIN  590.423.4569  6/25/2005
# 6          106      Valli  Pataballa  VPATABAL  590.423.4560   2/5/2006
# 7          107      Diana    Lorentz  DLORENTZ  590.423.5567   2/7/2007
#
#     JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID Status
# 1    AD_VP   17000             NaN       100.0           90.0   High
# 2    AD_VP   17000             NaN       100.0           90.0   High
# 3  IT_PROG    9000             NaN       102.0           60.0    Low
# 4  IT_PROG    6000             NaN       103.0           60.0    Low
# ...

# %%
job_list = [
    'AD_VP',
    'IT_PROG'
]
emp_job_in = df[df['JOB_ID'].isin(job_list)]
emp_job_in.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/2005
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/2001
# 3          103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/2006
# 4          104      Bruce     Ernst    BERNST  590.423.4568  5/21/2007
# 5          105      David    Austin   DAUSTIN  590.423.4569  6/25/2005
#
#     JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID Status
# 1    AD_VP   17000             NaN       100.0           90.0   High
# 2    AD_VP   17000             NaN       100.0           90.0   High
# 3  IT_PROG    9000             NaN       102.0           60.0    Low
# 4  IT_PROG    6000             NaN       103.0           60.0    Low
# 5  IT_PROG    4800             NaN       103.0           60.0    Low

# %%
emp_detail = df[(df['SALARY'] > 8000) & ((df['DEPARTMENT_ID'] == 60) | (df['DEPARTMENT_ID'] == 70))]
emp_detail
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME    EMAIL  PHONE_NUMBER HIRE_DATE  \
# 3            103  Alexander    Hunold  AHUNOLD  590.423.4567  1/3/2006
# 104          204    Hermann      Baer    HBAER  515.123.8888  6/7/2002
# 108          204    Hermann      Baer    HBAER  515.123.8888  6/7/2002
#
#       JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID Status
# 3    IT_PROG    9000             NaN       102.0           60.0    Low
# 104   PR_REP   10000             NaN       101.0           70.0    Low
# 108   PR_REP   10000             NaN       101.0           70.0    Low

# %%
new_df = pd.read_csv("Dataset/HR_Dataset Refresh.csv")
new_df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
# filter single boolean condition
filter = new_df[new_df['Department'] == 'IT/IS']
filter[['Department', 'EmpID', 'Employee_Name']].head()
# Out:
#    Department  EmpID             Employee_Name
# 1       IT/IS  10084  Ait Sidi, Karthikeyan
# 9       IT/IS  10250        Bacong, Alejandro
# 12      IT/IS  10012          Barbossa, Hector
# 18      IT/IS  10245             Becker, Renee
# 20      IT/IS  10084  Ait Sidi, Karthikeyan

# %%
# multi-condition filtering using and (&)
new_df['Department'] = new_df['Department'].str.strip()
filter = new_df[(new_df['Department'] == 'Production') & (new_df['EmpSatisfaction'] < 3)]
filter[['Department','EmpSatisfaction']].head(5)
# Out:
#      Department  EmpSatisfaction
# 73   Production                2
# 88   Production                2
# 102  Production                1
# 156  Production                2
# 207  Production                2

# %%
## multi-condition filtering using or(|)
filter = new_df[new_df['RecruitmentSource'].isin(['Glassdoor','Employee Referral'])]
filter.head()
# Out:
#        Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 7        Athwal, Sam  10062          0                4         1
# 16  Beak, Kimberly    10023          1                1         0
# 26       Athwal, Sam  10062          0                4         1
# 35  Beak, Kimberly    10023          1                1         0
# 52     Burke, Joelle  10107          0                0         0
#
#     EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 7             1       5            3                       0   59365  ...
# 16            2       5            4                       0   70131  ...
# 26            1       5            3                       0   59365  ...
# 35            2       5            4                       0   70131  ...
# 52            1       5            3                       0   63763  ...
#
#       ManagerName  ManagerID  RecruitmentSource PerformanceScore  \
# ...

# %%
# numeric ranges and column slicing
filter = new_df[(new_df['Salary'] > 100000) & (new_df['Absences'] > 10)]
filter[['Employee_Name','Position','ManagerName']].head()
# Out:
#                 Employee_Name                Position      ManagerName
# 1    Ait Sidi, Karthikeyan                    Sr. DBA       Simon Roup
# 20   Ait Sidi, Karthikeyan                    Sr. DBA       Simon Roup
# 74             Corleone, Vito  Director of Operations       Janet King
# 115               Foss, Jason             IT Director  Jennifer Zamora
# 150           Houlihan, Debra       Director of Sales       Janet King

# %%
emp_mgr = new_df[(new_df['ManagerName'] == 'Kissy Sullivan') & (new_df['DaysLateLast30'] > 0)]
emp_mgr.head()
# Out:
#      Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 72   Cole, Spencer  10292          0                0         1            4
# 224   O'hare, Lynn  10303          0                0         0            4
#
#      DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...     ManagerName  \
# 72        5            2                       0   59144  ...  Kissy Sullivan
# 224       5            1                       0   52674  ...  Kissy Sullivan
#
#      ManagerID RecruitmentSource   PerformanceScore  EngagementSurvey  \
# 72        20.0          LinkedIn  Needs Improvement              2.00
# 224       20.0          LinkedIn                PIP              2.33
#
#     EmpSatisfaction SpecialProjectsCount LastPerformanceReview_Date  \
# 72                3                    0                   5/1/2016
# 224               2                    0                   3/9/2018
#
#     DaysLateLast30 Absences
# 72               5       16
# ...
