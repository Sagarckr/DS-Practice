# %%
'''  
Machine Learning 
-----------------
Type of Machine Learning
-----------------
1. Supervised Learning:
    Feature -> All features must be independent to one another.
    Target -> Target must be dependent to all feature.

    1. Regression
        -> If our target value is continuous use it
    ----------------------------
    Algorithm: 
        1. Linear Regression
        2. Random Forest Regressor
        3. Decision Tree Regressor
        4. XGBoost Regressor
        5. K Nearest Neighbors Regressor
        6. Support Vector Regressor

    2. Classification
        -> If our target value is categorical or discrete then use it.
    ----------------------------
    Algorithm: 
        1. Logistic Regression
        2. Random Forest Classifier
        3. Decision Tree Classifier
        4. XGBoost Classifier
        5. K Nearest Neighbors Classifier
        6. Support Vector Classifier
        
        
2. Unsupervised Learning
    Feature -> All features must be independent to one another.

    1. Clustering
        -> Segmentation
    ----------------------------
    Algorithm:
        1. Agglomerative Clustering
        2. Hierarchical Clustering
        3. K Means Clustering
        4. PCA (Principle Component Analysis)


3. Reinforcement Learning -> Deep Learning
    
'''
# Out:
# '  \nMachine Learning \n-----------------\nType of Machine Learning\n-----------------\n1. Supervised Learning:\n    Feature -> All features must be independent to one another.\n    Target -> Target must be dependent to all feature.\n\n    1. Regression\n        -> If our target value is continuous use it\n    ----------------------------\n    Algorithm: \n        1. Linear Regression\n        2. Random Forest Regressor\n        3. Decision Tree Regressor\n        4. XGBoost Regressor\n        5. K Nearest Neighbors Regressor\n        6. Support Vector Regressor\n\n    2. Classification\n        -> If our target value is categorical or discrete then use it.\n    ----------------------------\n    Algorithm: \n        1. Logistic Regression\n        2. Random Forest Classifier\n        3. Decision Tree Classifier\n        4. XGBoost Classifier\n        5. K Nearest Neighbors Classifier\n        6. Support Vector Classifier\n\n\n2. Unsupervised Learning\n    Feature -> All features must
# ...

# %%
'''

    Feature Scaling
    ----------------------
    1. Standard Scaler
        -> IF row of data contains outliers or chance of getting outliers.
        -> (Xi - mean)/sd
        -> Best Range (-1 to 1)
        -> (-3 to 3) -> Consider

    2. Min Max Scaler
        -> If row of data does not contains my outliers or change of getting outliers.
        -> (Xi - min)/(max - min)
        -> 0 - 1

    3. Robust Scaler

    4. Feature Scaler

    Feature Encoding
    ----------------------
    1. Label Encoder
    2. One Hot Encoder

    Train Test Rule
    ----------------------
    80/20 Rule -> 80% Train and 20% Test
    70/30
    60/40
    50/50

'''
# Out:
# '\n\n    Feature Scaling\n    ----------------------\n    1. Standard Scaler\n        -> IF row of data contains outliers or chance of getting outliers.\n        -> (Xi - mean)/sd\n        -> Best Range (-1 to 1)\n        -> (-3 to 3) -> Consider\n\n    2. Min Max Scaler\n        -> If row of data does not contains my outliers or change of getting outliers.\n        -> (Xi - min)/(max - min)\n\n    Feature Encoding\n    ----------------------\n    1. Label Encoder\n    2. One Hot Encoder\n\n    Train Test Rule\n    ----------------------\n\n'

# %%
'''

Metrics
-----------------
1. Regression
    -> MAE (Mean Absolute Error) -> sum of all distance / total_data
    -> MSE (Mean Squared Error) -> sum of square distance / total_data
    -> RMSE (Root Mean Squared Error) -> root(MSE) -> Loss function / residual error
    -> R2 Score (Residual Score) -> Accuracy

    -> RMSE Increase - R2 Score Decrease
    -> RMSE Decrease - R2 Score Increase (Correct)

Bo -> Intercept(C)
B1 -> Cofficient / Slope(m)

MLR -> B0 + B1*x1 + B2*x2 + .......... + Bn*xn + e

'''

# %%
'''

    Linear Regression
    --------------------------
    y = mX + c
    y - Prediction Value
    m - Slope
    X - Data
    c - Intercept

'''

# %%
'''

    Logistic Regression
    --------------------------
    Classification Algorithm
        -> Binary Classification

        1. Feature and Target

        2. Train and Test
            - Feature(X), Target(Y), test_size = 0.2, random_state = 42, stratify = Target(Y) (compulsary for classification algorithm)
            
            eg:
            Healthy -> 70%
            Unhealthy -> 30% (healthy is more so bias)

            so,
            healthy -> 70% bata 10% 
            unhealthy -> 30% bata 10%

        3. Feature Scaling

        4. Define Model
            model = LogisticRegression(
                solver = liblinear, lbfgs, saga,
                class_weight = None(default), balanced, (logistic -> compulsary)
                random_state = 42 (default)
            )

            model.fit(x_train, y_train)
            model.predict(x_test)
        
            5. Metrics
                a. Classification Report
                    - Precision
                    - Recall
                    - F1-Score
                    - Support
                    - Accuracy
                    - Macro AVG
                    - Weighted AVG

                b. Confusion Matrix
                    - Heatmap
                    - True Positive
                    - False Positive
                    - False Negative
                    - True Negative
            
'''

# %%
'''

KNN (K Nearest Neighbor)
------------------------

Classification Algorithm
- Regression and Classification
- Lazy Algorithm

Distance (root(x2-x1)2 + (y2-y1)2)
if i have 100000 data point then distance for 100000 * 100000 is calculated to find nearest point.

Error Rate (Elbow Method)
--------------------------

- To choose optimal number of neighbors
- total number of wrong prediction / total test record

Data 
-------------
20 Students
-----

x_train -> 16 train (used to get wrong prediction)
x_test -> 4 train
y_train -> 16 test 
y_test -> 4 test (total test record)

code for elbow method
-------------------
- used to find elbow
- elbow -> optimal error rate (lowest error point)
- best range for knn (3 to 7)
- considerable upto 9

k_range = range(1, 21) # 1-20
error_rate = []

for i in k_range:
    knn = KNearestClassifier(k_neighbors = i)
    knn.fit(x_train, Y_train)
    k_pred = knn.predict(x_test)
    error_rate.append(np.mean(y_test != y_pred))

'''

# %%
'''

SVM (Support Vector Machine)
-------------------------------
Classification and Regression

Support Vector Classifier
Support Vector Regressor

It requires small dataset to work.

Figure:
- Hyperplance
- Margin
- Support Vector

5 - 7k

70000 -> Extract sample (5 - 7k)

Model Arguments
---------------------
Kernel -> Linear, rbf, polynomial
C -> 1.0(default), 0.01, 0.1
gamma -> scale, 1.0, 0.001, 0.01, 1.0

Linear -> if our data is linearly seperable then use linear.

- if our data is not linearly seperable then use RBF / Polynomial
- RBF (Radial Basis Function)
- Polynomial


'''
