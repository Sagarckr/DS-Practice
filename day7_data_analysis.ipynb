# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Dataset/cleaned_data1.csv")
df.head()
# Out:
#            Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi  Wilson  K  10026          0                0         1
# 1  Ait Sidi  Karthikeyan  10084          1                1         1
# 2      Akinkuolie  Sarah  10196          1                1         0
# 3           Alagbe Trina  10088          1                1         0
# 4        Anderson  Carol  10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    Absences  HireYear HireMonth HireDay  HireMonthName HireDayName  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
# find total employees working in departments.
df['Department'].value_counts()
# Out:
# Department
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: count, dtype: int64

# %%
# group by (categorical) + 
    #   aggregate function (categorical, continues,continues,discrete) 
        #   -> used in analysis
# aggregate function only -> used in KPIs (mean, min, max, count, sum)

# %%
emp_dep = df.groupby('Department')['EmpID'].count().reset_index().rename(
    columns = {
        'EmpID': 'Total_Employees'
    }
).sort_values(
    by = 'Total_Employees', ascending = False, ignore_index = True)
emp_dep
# Out:
#              Department  Total_Employees
# 0            Production              209
# 1                 IT/IS               50
# 2                 Sales               31
# 3  Software Engineering               11
# 4         Admin Offices                9
# 5      Executive Office                1

# %%
# find total salary distributed to each employee by their job position.

# %%
pos_sal = df.groupby('Position')['Salary'].sum().reset_index()
pos_sal.head()
# Out:
#                    Position   Salary
# 0              Accountant I   190523
# 1  Administrative Assistant   156840
# 2        Area Sales Manager  1753179
# 3              BI Developer   381860
# 4               BI Director   110929

# %%
pos_sal['Salary'] = pos_sal['Salary'].map("Rs.{:,.2f}".format)
pos_sal.head()
# Out:
#                    Position           Salary
# 0              Accountant I    Rs.190,523.00
# 1  Administrative Assistant    Rs.156,840.00
# 2        Area Sales Manager  Rs.1,753,179.00
# 3              BI Developer    Rs.381,860.00
# 4               BI Director    Rs.110,929.00

# %%
def currencyConverter(dataframe, prefix, *args):
    for col in args:
        dataframe[col] = dataframe[col].map(f"{prefix}""{:,.2f}".format)

# %%
emp_pos_details = df.groupby('Position').agg(
    Total_Salary = ('Salary', 'sum'),
    Total_Employees = ('EmpID', 'count'),
    Max_Salary = ('Salary', 'max'),
    Min_Salary = ('Salary', 'min'),
    Avg_Salary = ('Salary', 'mean')
).reset_index()
emp_pos_details.columns = emp_pos_details.columns.str.replace('_', ' ')

currencyConverter(emp_pos_details, 'Rs.', 'Total Salary', 'Max Salary',
                  'Min Salary', 'Avg Salary')

emp_pos_details.head()
# Out:
#                    Position     Total Salary  Total Employees     Max Salary  \
# 0              Accountant I    Rs.190,523.00                3   Rs.64,520.00
# 1  Administrative Assistant    Rs.156,840.00                3   Rs.55,000.00
# 2        Area Sales Manager  Rs.1,753,179.00               27   Rs.74,326.00
# 3              BI Developer    Rs.381,860.00                4   Rs.99,020.00
# 4               BI Director    Rs.110,929.00                1  Rs.110,929.00
#
#       Min Salary     Avg Salary
# 0   Rs.63,000.00   Rs.63,507.67
# 1   Rs.49,920.00   Rs.52,280.00
# 2   Rs.55,875.00   Rs.64,932.56
# 3   Rs.90,100.00   Rs.95,465.00
# 4  Rs.110,929.00  Rs.110,929.00

# %%
def convertDateTime(dataframe, *args):
    for col in args:
        dataframe[col] = pd.to_datetime(dataframe[col], format = 'mixed')

convertDateTime(df, 'DOB', 'DateofHire', 'DateofTermination', 'LastPerformanceReview_Date')

# %%
df.head(2)
# Out:
#            Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0    Adinolfi  Wilson  K  10026          0                0         1
# 1  Ait Sidi  Karthikeyan  10084          1                1         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
#
#    Absences  HireYear HireMonth HireDay  HireMonthName HireDayName  \
# 0         1      2011         7       5           July     Tuesday
# 1        17      2015         3      30          March      Monday
#
#       SalaryLabel Salary_Num     Sal1    Sal2
# 0      Low Salary          0      Low  Salary
# 1  Average Salary          1  Average  Salary
#
# [2 rows x 45 columns]

# %%
# find total employees hired in each different year.
emp_year = df.groupby('HireYear')['EmpID'].count().reset_index().rename(
    columns = {
        'HireYear':'Hire Year', 'EmpID': 'Total Employees'
    }
)

emp_year['Hire_PCT_YoY'] = emp_year['Total Employees'].pct_change().fillna(0)*100
emp_year['Hire_PCT_YoY'] = emp_year['Hire_PCT_YoY'].map('{:,.2f}%'.format)
emp_year.head()
# Out:
#    Hire Year  Total Employees Hire_PCT_YoY
# 0       2006                1        0.00%
# 1       2007                2      100.00%
# 2       2008                3       50.00%
# 3       2009                7      133.33%
# 4       2010                9       28.57%

# %%
month_emp = df.groupby(['HireMonth','HireMonthName'])['EmpID'].count().reset_index()
month_emp.head()
# Out:
#    HireMonth HireMonthName  EmpID
# 0          1       January     54
# 1          2      February     31
# 2          3         March     19
# 3          4         April     27
# 4          5           May     33

# %%
month_emp[['HireMonthName','EmpID']]
# Out:
#    HireMonthName  EmpID
# 0        January     54
# 1       February     31
# 2          March     19
# 3          April     27
# 4            May     33
# 5           June      8
# 6           July     44
# 7         August     20
# 8      September     39
# 9        October      7
# 10      November     28
# 11      December      1

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Gender', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences', 'HireYear', 'HireMonth', 'HireDay', 'HireMonthName',
#        'HireDayName', 'SalaryLabel', 'Salary_Num', 'Sal1', 'Sal2'],
#       dtype='object')

# %%
df['HireDayName'].unique()
# Out:
# array(['Tuesday', 'Monday', 'Thursday', 'Wednesday', 'Sunday', 'Friday',
#        'Saturday'], dtype=object)

# %%
# weekday = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Friday', 'Saturday']
# df['HireDayName'] =pd.Categorical(df['HireDayName'],categories = weekday)

# %%
# hire_day = df.groupby('HireDayName', observed=False)['EmpID'].count().reset_index()
# hire_day

# %%
day_dict = {
    'Sunday': 1,
    'Monday': 2,
    'Tuesday': 3,
    'Wednesday': 4,
    'Thursday': 5,
    'Friday': 6,
    'Saturday': 7
}

df['Day_num'] = df['HireDayName'].map(day_dict)

# %%
df['Day_num'].unique()
# Out:
# array([3, 2, 5, 4, 1, 6, 7])

# %%
emp_hire_day_num = (
    df.groupby(['Day_num', 'HireDayName'])['EmpID']
      .count()
      .reset_index(name='Employee_Count')
)

emp_hire_day_num
# Out:
#    Day_num HireDayName  Employee_Count
# 0        1      Sunday               6
# 1        2      Monday             259
# 2        3     Tuesday              19
# 3        4   Wednesday               9
# 4        5    Thursday               9
# 5        6      Friday               6
# 6        7    Saturday               3

# %%
# Find total employees and their salary distrubuted by each departments 
# and its marital description.

# %%
emp_sal_dis = (
    df.groupby(['DeptID', 'MaritalStatusID'])
      .agg(
          Total_Employees=('EmpID', 'count'),
          Total_Salary=('Salary', 'sum')
      )
      .reset_index()
)

emp_sal_dis.head()
# Out:
#    DeptID  MaritalStatusID  Total_Employees  Total_Salary
# 0       1                0                2        114923
# 1       1                1                7        550047
# 2       1                2                1         64520
# 3       2                1                1        250000
# 4       3                0               21       2247368

# %%
total_salary = df['Salary'].sum()
print(total_salary)
# Out:
# 21465433

# %%
# nunique -> number of unique record
print(df['DeptID'].nunique())
# Out:
# 6
